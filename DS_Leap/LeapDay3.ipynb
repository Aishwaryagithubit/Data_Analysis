# %%
import numpy as  np

# %%
num1 = np.array([1,2,3,4,5])
num2 = np.array([6,7,8,9,10])
print(num1)
# Out:
# [1 2 3 4 5]

# %%
sum = num1 + num2
print(sum)
# Out:
# [ 7  9 11 13 15]

# %%
print(num1.mean())
# Out:
# 3.0

# %%
num2 = [3,9,4,5,8]

# %%
print(np.sort(num2))
# Out:
# [3 4 5 8 9]

# %%
print(np.sqrt(num2))
# Out:
# [1.73205081 3.         2.         2.23606798 2.82842712]

# %%
print(np.exp(num2))
# Out:
# [  20.08553692 8103.08392758   54.59815003  148.4131591  2980.95798704]

# %%
print(np.add(num1,num2))
# Out:
# [ 4 11  7  9 13]

# %% [markdown]
# # Mathematical Operations

# %%
x = np.array([-2,-1,0,1,2])
y = np.array([10,20,30,40,50])
z = np.array([1,2,3,4,5])

# %%
print(np.add(x,y,z))
# Out:
# [ 8 19 30 41 52]

# %%
print(np.subtract(x,y,z))
# Out:
# [-12 -21 -30 -39 -48]

# %%
print(np.multiply(x,y,z))
# Out:
# [-20 -20   0  40 100]

# %%
x = np.array([-2,-1,0,1,2])
y = np.array([10,20,30,40,50])
z = np.array([1,2,3,4,5])

# %%
print(np.divide(y,z))
# Out:
# [10. 10. 10. 10. 10.]

# %%
print(np.power(z,2))
# Out:
# [ 1  4  9 16 25]

# %%
print(np.absolute(x))
# Out:
# [2 1 0 1 2]

# %%
print(np.negative(x))
# Out:
# [ 2  1  0 -1 -2]

# %%
print(np.mod(y,3))
# Out:
# [1 2 0 1 2]

# %% [markdown]
# # Trigonometry & Exponential

# %%
print(np.sin([0,np.pi/2]))
# Out:
# [0. 1.]

# %%
print(np.cos([0,np.pi]))
# Out:
# [ 1. -1.]

# %%
print(np.exp(x))
# Out:
# [0.13533528 0.36787944 1.         2.71828183 7.3890561 ]

# %%
print(np.log([1,np.e]))
# Out:
# [0. 1.]

# %%
print(np.log10([10,100]))
# Out:
# [1. 2.]

# %%
z
# Out:
# array([-20, -20,   0,  40, 100])

# %%
print(np.sqrt(z))
# Out:
# [        nan         nan  0.          6.32455532 10.        ]
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16388\2942609040.py:1: RuntimeWarning: invalid value encountered in sqrt
#   print(np.sqrt(z))

# %% [markdown]
# # Comparison & Logic

# %%
x = np.array([-2,-1,0,1,2])
y = np.array([10,20,30,40,50])
z = np.array([1,2,3,4,5])

# %%
print(np.greater(z,3))
# Out:
# [False False False  True  True]

# %%
print(np.less(z,3))
# Out:
# [ True  True False False False]

# %%
print(np.equal(z,3))
# Out:
# [False False False False False]

# %%
print(np.logical_and (z > 2, z < 5))
# Out:
# [False False  True  True False]

# %%
print(np.logical_or (z < 2, z > 4))
# Out:
# [ True False False False  True]

# %%
print(np.sin(x))
# Out:
# [-0.90929743 -0.84147098  0.          0.84147098  0.90929743]

# %%
print (np.logical_not ( z > y, z < x ))
# Out:
# [ True  True  True  True  True]

# %%
print(np.cos([1, np.pi]))
# Out:
# [ 0.54030231 -1.        ]

# %%
print(np.cos([0, np.pi/2, np.pi, 2*np.pi]))
# Out:
# [ 1.000000e+00  6.123234e-17 -1.000000e+00  1.000000e+00]
