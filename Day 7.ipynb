# %%
#Data Cleaning
import pandas as pd
import openpyxl
print(openpyxl.__version__)
# Out:
# 3.1.5

# %%
df = pd.read_excel(r"C:\Users\ASUS\Desktop\DataPy\cleandata.xlsx") 
df
# Out:
#    EmployeeID       Name   Age Department   Salary    JoinDate        City  \
# 0         101      Alice  25.0         HR  45000.0  2023-01-15   Kathmandu
# 1         102        Bob   NaN         IT  55000.0  2022-05-10     Pokhara
# 2         103   Charlie   29.0    Finance  60000.0  2021-03-12         NaN
# 3         104       Dana  35.0         IT      NaN  2020-11-01    Lalitpur
# 4         104       Dana  35.0         IT      NaN  2020-11-01    Lalitpur
# 5         105        NaN  42.0         HR  52000.0  2019-07-20   Bhaktapur
# 6         106      Frank  -5.0      Sales  48000.0  2024-02-30  Biratnagar
# 7         107      Grace  31.0  Marketing  70000.0  2022-08-18   Kathmandu
# 8         108      Henry  28.0         IT  58000.0  2023-04-05     Pokhara
# 9         109        Ivy  27.0    Finance  61000.0  2023-06-25   Kathmandu
#
#                  Email
# 0    alice@example.com
# 1      bob@example.com
# 2  charlie@example.com
# 3         dana@example
# ...

# %%
df.drop_duplicates()   #remove duplicates
# Out:
#    EmployeeID       Name   Age Department   Salary    JoinDate        City  \
# 0         101      Alice  25.0         HR  45000.0  2023-01-15   Kathmandu
# 1         102        Bob   NaN         IT  55000.0  2022-05-10     Pokhara
# 2         103   Charlie   29.0    Finance  60000.0  2021-03-12         NaN
# 3         104       Dana  35.0         IT      NaN  2020-11-01    Lalitpur
# 5         105        NaN  42.0         HR  52000.0  2019-07-20   Bhaktapur
# 6         106      Frank  -5.0      Sales  48000.0  2024-02-30  Biratnagar
# 7         107      Grace  31.0  Marketing  70000.0  2022-08-18   Kathmandu
# 8         108      Henry  28.0         IT  58000.0  2023-04-05     Pokhara
# 9         109        Ivy  27.0    Finance  61000.0  2023-06-25   Kathmandu
#
#                  Email
# 0    alice@example.com
# 1      bob@example.com
# 2  charlie@example.com
# 3         dana@example
# 5      eva@example.com
# 6    frank@example.com
# 7    grace@example.com
# 8    henry@example.com
# ...

# %%
df = df.drop_duplicates() 
df
# Out:
#    EmployeeID       Name   Age Department   Salary    JoinDate        City  \
# 0         101      Alice  25.0         HR  45000.0  2023-01-15   Kathmandu
# 1         102        Bob   NaN         IT  55000.0  2022-05-10     Pokhara
# 2         103   Charlie   29.0    Finance  60000.0  2021-03-12         NaN
# 3         104       Dana  35.0         IT      NaN  2020-11-01    Lalitpur
# 5         105        NaN  42.0         HR  52000.0  2019-07-20   Bhaktapur
# 6         106      Frank  -5.0      Sales  48000.0  2024-02-30  Biratnagar
# 7         107      Grace  31.0  Marketing  70000.0  2022-08-18   Kathmandu
# 8         108      Henry  28.0         IT  58000.0  2023-04-05     Pokhara
# 9         109        Ivy  27.0    Finance  61000.0  2023-06-25   Kathmandu
#
#                  Email
# 0    alice@example.com
# 1      bob@example.com
# 2  charlie@example.com
# 3         dana@example
# 5      eva@example.com
# 6    frank@example.com
# 7    grace@example.com
# 8    henry@example.com
# ...

# %%
#df.drop(columns = 'Age') # drop that column

df['Name'].str.strip()
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3       Dana
# 5        NaN
# 6      Frank
# 7      Grace
# 8      Henry
# 9        Ivy
# Name: Name, dtype: object

# %%
#clean phone number
#df['phone_number'].str.replace('^a-zA-Z0-9', '')

#remove NAN
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df['Age'].str.strip()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6321, in NDFrame.__getattr__(self, name)
#    6314 if (
#    6315     name not in self._internal_names_set
#    6316     and name not in self._metadata
#    6317     and name not in self._accessors
#    6318     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319 ):
#    6320     return self[name]
# -> 6321 return object.__getattribute__(self, name)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
# ...
