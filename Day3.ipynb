# %%
#file explorer
import os, shutil

# %%
path = r"C:/Users/ASUS/Desktop/DataPy/python projects/project2/"
# r read as raw string

# %%
os.listdir(path)   #what files are in that folder
# Out:
# ['ava2.png', 'csv files', 'grades.csv', 'image files', 'text files', 'txt.txt']

# %%
for loop in range(len(folder_names)):
    folder_path = os.path.join(path, folder_names[loop])  # safer than string concatenation
    if not os.path.exists(folder_path):
        print("Creating:", folder_path)
        os.makedirs(folder_path)

# %%
file_names = os.listdir(path)

# %%
for file in file_names:
     if ".csv" in file and not os.path.exists(path + "csv files/" + file):
        shutil.move(path + file, path + "csv files/" + file)
     elif ".txt" in file and not os.path.exists(path + "text files/" + file):
        shutil.move(path + file, path + "text files/" + file)
     elif ".png" in file and not os.path.exists(path + "image files/" + file):
        shutil.move(path + file, path + "image files/" + file)
     else:
         print("some files are not moved!!")
# Out:
# some files are not moved!!
# some files are not moved!!
# some files are not moved!!
# some files are not moved!!
